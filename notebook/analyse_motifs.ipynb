# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
hcv_1 = pd.read_csv("../Resultat/half_HCV_1.csv", sep=';')

# %%
hcv_2 = pd.read_csv("../Resultat/HCV_CLEAN_ORIG.csv", sep=';')

# %%
hcv_1
# Out:
#                 Dataset  Support  Size  Temps d'exécution (s)
# 0  ./data/Clean/HCV.csv     0.04  4716             903.876701  \
# 1  ./data/Clean/HCV.csv     0.08  2216             205.292393
# 2  ./data/Clean/HCV.csv     0.10  1525             100.696959
# 3  ./data/Clean/HCV.csv     0.14   813              36.768094
# 4  ./data/Clean/HCV.csv     0.18   589              23.931488
# 5  ./data/Clean/HCV.csv     0.16   697              27.840455
# 6  ./data/Clean/HCV.csv     0.20   496              20.052196
# 7  ./data/Clean/HCV.csv     0.24   272              13.089063
# 8  ./data/Clean/HCV.csv     0.28   176              10.491139
#
#    Mémoire maximale (Ko)                                    Titre variables
# 0            3546.357422  ['1 : Age', '2 : ALB', '3 : ALP', '4 : ALT', '...  \
# 1            1349.550781  ['1 : Age', '2 : ALB', '3 : ALP', '4 : ALT', '...
# 2             877.844727  ['1 : Age', '2 : ALB', '3 : ALP', '4 : ALT', '...
# ...

# %%
hcv_2
# Out:
#                  Dataset  Support  Size  Temps d'exécution (s)
# 0   ./data/Clean/HCV.csv     0.04  4716             856.859834  \
# 1   ./data/Clean/HCV.csv     0.08  2216             189.039778
# 2   ./data/Clean/HCV.csv     0.10  1525              94.282152
# 3   ./data/Clean/HCV.csv     0.14   813              34.956580
# 4   ./data/Clean/HCV.csv     0.18   589              22.955824
# 5   ./data/Clean/HCV.csv     0.16   697              26.754105
# 6   ./data/Clean/HCV.csv     0.20   496              19.253927
# 7   ./data/Clean/HCV.csv     0.24   272              12.649659
# 8   ./data/Clean/HCV.csv     0.28   176              10.110895
# 9   ./data/Clean/HCV.csv     0.30   150               9.638912
# 10  ./data/Clean/HCV.csv     0.34   120               9.240743
# 11  ./data/Clean/HCV.csv     0.38    94               8.967299
# 12  ./data/Clean/HCV.csv     0.40    94               8.862499
# 13  ./data/Clean/HCV.csv     0.50    48               7.565296
# ...

# %%
#hcv_2.to_excel("../data/serveur/HCV.xlsx", index=False)

# %%
hcv_pca = pd.read_csv("../Resultat/Half_Pca_hcv.csv", sep=';')

# %%
#hcv_pca.head(20).to_excel('../data/serveur/HCV_PCA.xlsx', index=False)

# %%
Air_acp = pd.read_csv("../Resultat/Air quality ACP.csv", sep=';')

# %%
#Air_acp.to_excel('../data/serveur/Air Quality_PCA.xlsx', index=False)

# %%
Air = pd.read_csv("../Resultat/Air_Quality_CLEAN_reverse.csv", sep=';')

# %%
#Air.sort_values(by='Support', ascending=True).to_excel("../data/serveur/Air Quality.xlsx", index=False)

# %%
check_pca = pd.read_csv("../Chickenpox_origin_reverse_1.csv", sep=';')

# %%
check_pca
# Out:
#                        Dataset  Support   Size  Temps d'exécution (s)
# 0  ./data/Clean/Chickenpox.csv     0.34  41522          172638.235327  \
#
#    Mémoire maximale (Ko)                                    Titre variables
# 0           31800.433594  ['1 : BUDAPEST', '2 : BARANYA', '3 : BACS', '4...  \
#
#                                      Supports motifs
# 0  [0.34549679734668814, 0.35096079599355795, 0.3...  \
#
#                                      Motifs detectés
# 0  [{'7+', '4+', '17+', '6+', '1+', '18+'}, {'4+'...

# %%
checck1 = pd.read_csv("../Resultat/Chickenpox_origin_reverse.csv", sep=';')

# %%
checck1
# Out:
#                        Dataset  Support   Size  Temps d'exécution (s)
# 0  ./data/Clean/Chickenpox.csv     1.00      0               9.308707  \
# 1  ./data/Clean/Chickenpox.csv     0.90      0               9.789552
# 2  ./data/Clean/Chickenpox.csv     0.80      1               9.806202
# 3  ./data/Clean/Chickenpox.csv     0.70    117              11.580837
# 4  ./data/Clean/Chickenpox.csv     0.60    386              17.552623
# 5  ./data/Clean/Chickenpox.csv     0.50   2280             144.305780
# 6  ./data/Clean/Chickenpox.csv     0.40  16067           10529.315486
# 7  ./data/Clean/Chickenpox.csv     0.38  22932           30516.866726
#
#    Mémoire maximale (Ko)                                    Titre variables
# 0               6.962891                                                  0  \
# 1               5.668945                                                  0
# 2               7.034180  ['1 : BUDAPEST', '2 : BARANYA', '3 : BACS', '4...
# ...

# %%
checck1o = pd.read_csv("../Resultat/Chickenpox_origin_reverse.csv", sep=';')

# %%
checck1of = pd.read_csv("../Chickenpox_origin_reverse_1.csv", sep=';')

# %%
checck1o
# Out:
#                        Dataset  Support   Size  Temps d'exécution (s)
# 0  ./data/Clean/Chickenpox.csv     0.34  41522          172638.235327  \
#
#    Mémoire maximale (Ko)                                    Titre variables
# 0           31800.433594  ['1 : BUDAPEST', '2 : BARANYA', '3 : BACS', '4...  \
#
#                                      Supports motifs
# 0  [0.34549679734668814, 0.35096079599355795, 0.3...  \
#
#                                      Motifs detectés
# 0  [{'7+', '4+', '17+', '6+', '1+', '18+'}, {'4+'...

# %%
pd.concat([checck1,checck1o ], axis=0).sort_values("Support").to_excel("../data/serveur/Chickenpox.xlsx", index=False)

# %%
checck2 = pd.read_csv("../Chickenpox_origin_reverse_1.csv", sep=';')

# %%
chick  = pd.concat([checck1, checck2], axis = 0)

# %%
chick
# Out:
#                        Dataset  Support   Size  Temps d'exécution (s)
# 0  ./data/Clean/Chickenpox.csv     1.00      0               9.308707  \
# 1  ./data/Clean/Chickenpox.csv     0.90      0               9.789552
# 2  ./data/Clean/Chickenpox.csv     0.80      1               9.806202
# 3  ./data/Clean/Chickenpox.csv     0.70    117              11.580837
# 4  ./data/Clean/Chickenpox.csv     0.60    386              17.552623
# 5  ./data/Clean/Chickenpox.csv     0.50   2280             144.305780
# 6  ./data/Clean/Chickenpox.csv     0.40  16067           10529.315486
# 7  ./data/Clean/Chickenpox.csv     0.38  22932           30516.866726
# 0  ./data/Clean/Chickenpox.csv     0.34  41522          172638.235327
#
#    Mémoire maximale (Ko)                                    Titre variables
# 0               6.962891                                                  0  \
# 1               5.668945                                                  0
# ...

# %%
chekpca1 = pd.read_csv("../Resultat/results_gradual_all.csv", sep=';')

# %%
chekpca2 = pd.read_csv("../Resultat/results_gradual_Chickenpox_PCA.csv", sep=';')

# %%
chekpca1.columns
# Out:
# Index(['Dataset', 'Support', 'Size', 'Temps d'exécution (s)',
#        'Mémoire maximale (Ko)', 'Titre variables', 'Supports motifs',
#        'Motifs detectés'],
#       dtype='object')

# %%
chekpca2.columns
# Out:
# Index(['Dataset', 'Support', 'Size', 'Temps d'exécution (s)',
#        'Mémoire maximale (Ko)', 'Titre variables', 'Supports motifs',
#        'Motifs detectés'],
#       dtype='object')

# %%
chekpca = pd.concat([chekpca1, chekpca2], axis=0)

# %%
#chekpca.to_excel("../data/serveur/Chickenpox.xlsx", index=False)

# %%
cargo_acp = pd.read_csv("../new/Cargo_acp.csv", sep=";")

# %%
cargo = pd.read_csv("../new/Cargo_clean.csv", sep=";")

# %%
#cargo.sort_values("Support").to_excel("../data/serveur/Cargo.xlsx", index=False)

# %%
#cargo_acp.sort_values("Support").to_excel("../data/serveur/Cargo_PCA.xlsx", index=False)
